# %% [markdown]
# #Python Basics

# %% [markdown]
# Q1. What is Python, and why is it popular?
# - Python is a programming language. It is popular because of its simple rules, easy to read and understand, lots of readymade libreries, wide range of applications, integration capability with othre languages, strong community support  and it is opensourse.
#
#
# Q2. What is an interpreter in Python?
# - An interpreter runs pytho code line by line to translate HLL to machine language. it reads doce and immidiately does what the code says.
#
#
# Q3. What are pre-defined keywords in Python?
# - Keywords are special words that python already uses for its rules. Example- if, else, for, print, True.
#
#
# Q4.Can keywords be used as variable names?
# - No, doing this will cause error.
#
# Q5. What is mutability in Python?
# - Mutability means whether an object can be changed after it is created. If an object is mutable, its content can be changed.
#
#
# Q6. Why are lists mutable, but tuples are immutable?
# - List's purpose is to do some do some operations on them but tuples are meant to be fixed.
#
#
# Q7.  What is the difference between “==” and “is” operators in Python?
# - "==" checks wheather two values are equal. "is" checks wheather both objects are in same memory.
#
#
# Q8. What are logical operators in Python?
# - Logical operations always gives boolian value after combining and evaluating conditional statements. Example- and, or, not.
#
#
# Q9. What is type casting in Python?
# - Type casting means converting a value from one type to another. Example- from string to integer, from integer to float.
#
#
# Q10. What is the difference between implicit and explicit type casting?
# - Implicit casting hapens automatically by python, where as explicit casting is when the programmer converts types using functions.
#   Example:
#   Implicit casting- b + c
#   Explicit casting- int(b) + c
#
#
# Q11. What is the purpose of conditional statements in Python?
# - Purpose of conditional statement is to enabling dicission making and to control flow of execution of programme.
#
#
# Q12. How does the elif statement work?
# - "elif" means else if. It folows an if function, it executes when if function gives a "False" value.
#
#
# Q13. What is the difference between for and while loops?
# - "for" loop repeats a fixxed number of times or go through items in a sequence. it is uses when numer of iterations is known.
#  "while" loop is to repeat the process as long as a condition is True. It is used when number of iterations is unknown.
#
#
#  Q14. Describe a scenario where a while loop is more suitable than a for loop.
#  - Condition: keep asking a user for a password until they enter it corrently. in this case number of try is infinite or umknown.

# %% [markdown]
# #Practical Questions

# %%
# Q1. Write a Python program to print "Hello, World!y

print("Hello, World!")
# Out:
# Hello, World!

# %%
# Q2. Write a Python program that displays your name and age
name = "Tudu"
age = 24
print("Name: ", name)
print("Age: ", age)
# Out:
# Name:  Tudu
# Age:  24

# %%
# Q3.  Write code to print all the pre-defined keywords in Python using the keyword library8
import keyword
print(keyword.kwlist)

# %%
# Q4. Write a program that checks if a given word is a Python keyword.
import keyword
word = input("Enter a word: ")

if keyword.iskeyword(word):
  print(word, "is a keyword")
else:
  print(word, "is not a keyword")

# %%
# Q5. 5. Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.
list1 = [1, 2, 3, 4, 5]
tuple1 = (1, 2, 3, 4, 5)

list1[1] = 55
print(list1)   # There wil be no error and print the updated list

tuple1[1] = 25
print(tuple1)  # There will be an error and print, because a tuple is immutable

# to make any changes here we have to type cast tuple into list.
# Out:
# [1, 55, 3, 4, 5]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1282127272.py in <cell line: 0>()
#       6 print(list1)   # There wil be no error and print the updated list
#       7
# ----> 8 tuple1[1] = 25
#       9 print(tuple1)  # There will be an error and print, because a tuple is immutable
#      10
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Q6. Write a function to demonstrate the behavior of mutable and immutable arguments.
def change_number(x):
    x = x + 1
    print("Inside function (number):", x)

# Function for mutable argument
def change_list(lst):
    lst.append(100)
    print("Inside function (list):", lst)

# Testing immutable
num = 5
change_number(num)
print("Outside function (number):", num)

# Testing mutable
my_list = [1, 2, 3]
change_list(my_list)
print("Outside function (list):", my_list)
# Out:
# Inside function (number): 6
# Outside function (number): 5
# Inside function (list): [1, 2, 3, 100]
# Outside function (list): [1, 2, 3, 100]

# %%
# Q7. Write a program that performs basic arithmetic operations on two user-input numbers.
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Sum: ", num1 + num2)
print("Difference: ", abs(num1 - num2))
print("Product: ", num1 * num2)
print("Quotient: ", num1 / num2)
print("Reminder: ", num1 % num2)

# %%
# Q8. Write a program to demonstrate the use of logical operators.
a = True
b = False
print("a and b:", a and b)
print("a or b:", a or b)
print("negative of a:", not a)
print("negative of b:", not b)

# %%
# Q9.  Write a Python program to convert user input from string to integer, float, and boolean types.
num3 = input("Enter a number: ")
print(int(num3))    #type conversion into integer
print(float(num3))  #type conversion into folat
print(bool(num3))   ##type conversion into boolian value

# %%
# Q10. Write code to demonstrate type casting with list elements.
list2 = [2, 43.78, 429]

print(type(list2[0]), type(list2[1]), type(list2[2]))

new_list2 = [float(list2[0]), int(list2[1]), bool(list2[2])]
print(new_list2)
print(type(new_list2[0]), type(new_list2[1]), type(new_list2[2]))

# %%
# Q11. Write a program that checks if a number is positive, negative, or zero.
num4 = int(input("Input a number: "))

if num4 > 0:
  print("It is a positive number")
if num4 < 0:
  print("It is a negative number")
if num4 == 0:
  print("It is Zero")

# %%
# Q12. Write a for loop to print numbers from 1 to 10.
for i in range (1,11,1):
  print(i)

# %%
# Q13. Write a Python program to find the sum of all even numbers between 1 and 50.
indx_no = 1
total = 0
for i in range (2, 51, 2):
  total += i
print("sum of all even numbers between 1 and 50 is: ", total)

# %%
# Q14.  Write a program to reverse a string using a while loop.
str1 = "I am here"
print(str1[::-1])

# %%
# Q15.  Write a Python program to calculate the factorial of a number provided by the user using a while loop.
n = int(input("Enter an integer: "))
if n < 0:
  print("Factorial not defined for negative numbers")
else:
  fact = 1
  i = 1
while i <= n:
  fact *= i
  i += 1
print(f"{n}! =", fact)
